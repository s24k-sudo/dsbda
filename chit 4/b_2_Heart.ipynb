# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/RanjeetKumbhar01/TE_IT_DSBDA_ASSIGNMENTS_SPPU/blob/main/Group_B/B_2/b_2_Heart.ipynb">
#   <img align="left" alt="Goolge Colab"  src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
pip install numpy matplotlib seaborn scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (2.4.4)
# Requirement already satisfied: matplotlib in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (3.10.9)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scikit-learn in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (1.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tzdata in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\SOHAM\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# import pandas library
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.linear_model import LogisticRegression
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Reading csv file
df = pd.read_csv("Heart.csv")
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %% [markdown]
# ## Data Cleaning

# %%
df = df.drop_duplicates()

# %%
# Count ,min,max ,etc of each column
df.describe()
# Out:
#              age         sex          cp      trtbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# std      0.526027   22.903527    0.470196    1.161452    0.616274    1.006748
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.250000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  152.500000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#             thall      output
# count  302.000000  302.000000
# mean     2.314570    0.543046
# std      0.613026    0.498970
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
# Information about each column data
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 302 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trtbps    302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalachh  302 non-null    int64
#  8   exng      302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slp       302 non-null    int64
#  11  caa       302 non-null    int64
#  12  thall     302 non-null    int64
#  13  output    302 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 35.4 KB

# %%
#Finding null values in each column
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %% [markdown]
# ## Data Integration

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.fbs.unique()
# Out:
# array([1, 0])

# %%
subSet1 = df[['age','cp','chol','thalachh']]

# %%
subSet2 = df[['exng','slp','output']]

# %%
merged_df = pd.concat([subSet1, subSet2], axis=1)
merged_df.head()
# Out:
#    age  cp  chol  thalachh  exng  slp  output
# 0   63   3   233       150     0    0       1
# 1   37   2   250       187     0    0       1
# 2   41   1   204       172     0    2       1
# 3   56   1   236       178     0    2       1
# 4   57   0   354       163     1    2       1

# %% [markdown]
# ## Error Correcting

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='str')

# %%
def remove_outliers(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    threshold = 1.5 * IQR
    outlier_mask = (column < Q1 - threshold) | (column > Q3 + threshold)
    return column[~outlier_mask]

# %%
# Remove outliers for each column using a loop
col_name = ['cp','thalachh','exng','oldpeak','slp','caa']
for col in col_name:
    df[col] = remove_outliers(df[col])

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed

for col in col_name:
    sns.boxplot(data=df[col])
    plt.title(col)
    plt.show()

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
df = df.drop('fbs',axis=1)

# %%
# Compute correlations between features and target
correlations = df.corr()['output'].drop('output')

# Print correlations
print("Correlation with the Target:")
print(correlations)
print()

# Plot correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# Correlation with the Target:
# age        -0.193798
# sex        -0.303271
# cp          0.410807
# trtbps     -0.135238
# chol       -0.052796
# restecg     0.122071
# thalachh    0.384609
# exng       -0.444401
# oldpeak    -0.437895
# slp         0.329432
# caa        -0.460816
# thall      -0.366390
# Name: output, dtype: float64

# %%
# df.isna().sum()

# %% [markdown]
# ## Data Split

# %%
# splitting data using train test split
x = df[['cp','thalachh','exng','oldpeak','slp','caa']]
y = df.output
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((220, 6), (55, 6), (220,), (55,))

# %% [markdown]
# ## Data transformation

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# ## Data model building

# %%
y_train= np.array(y_train).ravel()
y_test= np.array(y_test).ravel()

# %%
y_train.shape
# Out:
# (220,)

# %%
model = LogisticRegression()
model.fit(x_train_scaled, y_train)

# Make predictions on the test set
y_pred = model.predict(x_test_scaled)

# Evaluate the model's accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8363636363636363

# %%
#Classification model using Decision Tree
from sklearn.tree import DecisionTreeClassifier
tc=DecisionTreeClassifier(criterion='entropy')
tc.fit(x_train_scaled,y_train)
y_pred=tc.predict(x_test_scaled)

print("Training Accuracy Score :",accuracy_score(y_pred,y_test))
print("Training Confusion Matrix  :",confusion_matrix(y_pred,y_test))
# Out:
# Training Accuracy Score : 0.8
# Training Confusion Matrix  : [[21  5]
#  [ 6 23]]
